# %%
import os

# %%
def file_len(fname):
    with open(fname) as f:
        for i, l in enumerate(f):
            pass
    return i + 1

# %%
def next_smaller_base2_int(number):
    nsb = 1
    while nsb < number:
        nsb *= 2
    return nsb/2

# %% [markdown]
# # Train OpenCV cascade classifier
# See [cascade training documentation]( http://docs.opencv.org/2.4/doc/user_guide/ug_traincascade.html#cascade-training).

# %%
obj = 'bin'

# %%
package_dirname = '/home/baxter/ros_ws/src/baxter_pick_and_place/'

data = os.path.join(package_dirname, 'data', 'synthetic_demo_data')
vec = os.path.join(data, '%s_20_20.vec' % obj)
bg = os.path.join(data, 'bg.txt')
num_stages = 14
precalc_val_buf_size = 256
precalc_idx_buf_size = 256
acceptance_ratio_break_value = 10e-5
feature_type = 'HAAR'
w = 20
h = 20
bt = 'GAB'
min_hit_rate = 0.999
weight_trim_rate = 0.95
max_depth = 1
mode = 'ALL'

num_neg = file_len(bg)
num_vec = file_len(os.path.join(data, '%s_info.dat' % obj))
num_pos = (num_vec - num_neg)/(1+(num_stages-1)*(1-min_hit_rate))
num_pos = next_smaller_base2_int(num_pos)

# %%
cmd = ('opencv_traincascade ' + 
       '-data %s ' % data +
       '-vec %s ' % vec + 
       '-bg %s ' % bg + 
       '-numPos %i ' % num_pos + 
       '-numNeg %i ' % num_neg + 
       '-numStages %i ' % num_stages + 
       '-precalcValBufSize %i ' % precalc_val_buf_size + 
       '-precalcIdxBufSize %i ' % precalc_idx_buf_size + 
       '-acceptanceRatioBreakValue %f ' % acceptance_ratio_break_value + 
       '-featureType %s ' % feature_type + 
       '-w %i ' % w + 
       '-h %i ' % h + 
       'bt %s ' % bt + 
       '-minHitRate %f ' % min_hit_rate + 
       '-weightTrimRate %f ' % weight_trim_rate + 
       '-maxDepth %i ' % max_depth + 
       '-mode %s' % mode)
print '%s\n'% cmd
# !{cmd}
# Out:
# opencv_traincascade -data /home/baxter/ros_ws/src/baxter_pick_and_place/data/synthetic_demo_data -vec /home/baxter/ros_ws/src/baxter_pick_and_place/data/synthetic_demo_data/bin_20_20.vec -bg /home/baxter/ros_ws/src/baxter_pick_and_place/data/sdd/bg.txt -numPos 2048 -numNeg 75 -numStages 14 -precalcValBufSize 256 -precalcIdxBufSize 256 -acceptanceRatioBreakValue 0.000100 -featureType HAAR -w 20 -h 20 bt GAB -minHitRate 0.999000 -weightTrimRate 0.950000 -maxDepth 1 -mode ALL
#
# PARAMETERS:
# cascadeDirName: /home/baxter/ros_ws/src/baxter_pick_and_place/data/synthetic_demo_data
# vecFileName: /home/baxter/ros_ws/src/baxter_pick_and_place/data/synthetic_demo_data/bin_20_20.vec
# bgFileName: /home/baxter/ros_ws/src/baxter_pick_and_place/data/sdd/bg.txt
# numPos: 2048
# numNeg: 75
# numStages: 14
# precalcValBufSize[Mb] : 256
# precalcIdxBufSize[Mb] : 256
# stageType: BOOST
# featureType: HAAR
# sampleWidth: 20
# sampleHeight: 20
# boostType: GAB
# minHitRate: 0.999
# maxFalseAlarmRate: 0.5
# weightTrimRate: 0.95
# maxDepth: 1
# maxWeakCount: 100
# mode: ALL
#
# ===== TRAINING 0-stage =====
# <BEGIN
# POS count : consumed   2048 : 2048
# NEG count : acceptanceRatio    75 : 1
# Precalculation time: 6
# +----+---------+---------+
# |  N |    HR   |    FA   |
# +----+---------+---------+
# |   1| 0.999023| 0.266667|
# +----+---------+---------+
# END>
# Training until now has taken 0 days 0 hours 0 minutes 53 seconds.
#
# ===== TRAINING 1-stage =====
# <BEGIN
# POS count : consumed   2048 : 2050
# NEG count : acceptanceRatio    75 : 0.337838
# Precalculation time: 5
# +----+---------+---------+
# |  N |    HR   |    FA   |
# +----+---------+---------+
# |   1|        1| 0.386667|
# +----+---------+---------+
# END>
# Training until now has taken 0 days 0 hours 1 minutes 47 seconds.
#
# ===== TRAINING 2-stage =====
# <BEGIN
# POS count : consumed   2048 : 2050
# NEG count : acceptanceRatio    75 : 0.213068
# Precalculation time: 5
# +----+---------+---------+
# |  N |    HR   |    FA   |
# +----+---------+---------+
# |   1| 0.999512| 0.826667|
# +----+---------+---------+
# |   2| 0.999512| 0.826667|
# +----+---------+---------+
# |   3| 0.999512|     0.84|
# +----+---------+---------+
# |   4| 0.999512| 0.853333|
# +----+---------+---------+
# |   5| 0.999512| 0.853333|
# +----+---------+---------+
# |   6| 0.999023| 0.586667|
# +----+---------+---------+
# |   7| 0.999512|     0.64|
# +----+---------+---------+
# |   8| 0.999512| 0.586667|
# +----+---------+---------+
# |   9| 0.999023|0.0533333|
# +----+---------+---------+
# END>
# Training until now has taken 0 days 0 hours 6 minutes 52 seconds.
#
# ===== TRAINING 3-stage =====
# <BEGIN
# POS count : consumed   2048 : 2052
# NEG count : acceptanceRatio    75 : 0.0930521
# Precalculation time: 6
# +----+---------+---------+
# |  N |    HR   |    FA   |
# +----+---------+---------+
# |   1| 0.999023| 0.706667|
# +----+---------+---------+
# |   2| 0.999023| 0.706667|
# +----+---------+---------+
# |   3| 0.999023|     0.72|
# +----+---------+---------+
# |   4|        1| 0.773333|
# +----+---------+---------+
# |   5|        1| 0.786667|
# +----+---------+---------+
# |   6|        1|     0.64|
# +----+---------+---------+
# |   7| 0.999512| 0.306667|
# +----+---------+---------+
# END>
# Training until now has taken 0 days 0 hours 11 minutes 12 seconds.
#
# ===== TRAINING 4-stage =====
# <BEGIN
# POS count : consumed   2048 : 2053
# NEG count : acceptanceRatio    75 : 0.0672646
# Precalculation time: 5
# +----+---------+---------+
# |  N |    HR   |    FA   |
# +----+---------+---------+
# |   1|        1|     0.68|
# +----+---------+---------+
# |   2|        1|     0.68|
# +----+---------+---------+
# |   3|        1| 0.733333|
# +----+---------+---------+
# |   4| 0.999023| 0.613333|
# +----+---------+---------+
# |   5|        1|     0.64|
# +----+---------+---------+
# |   6| 0.999023|     0.48|
# +----+---------+---------+
# END>
# Training until now has taken 0 days 0 hours 14 minutes 54 seconds.
#
# ===== TRAINING 5-stage =====
# <BEGIN
# POS count : consumed   2048 : 2055
# NEG count : acceptanceRatio    75 : 0.146484
# Precalculation time: 5
# +----+---------+---------+
# |  N |    HR   |    FA   |
# +----+---------+---------+
# |   1|        1|        1|
# +----+---------+---------+
# |   2|        1| 0.706667|
# +----+---------+---------+
# |   3| 0.999023| 0.466667|
# +----+---------+---------+
# END>
# Training until now has taken 0 days 0 hours 16 minutes 51 seconds.
#
# ===== TRAINING 6-stage =====
# <BEGIN
# POS count : consumed   2048 : 2057
# NEG count : acceptanceRatio    75 : 0.245098
# Precalculation time: 5
# +----+---------+---------+
# |  N |    HR   |    FA   |
# +----+---------+---------+
# |   1| 0.999512|     0.48|
# +----+---------+---------+
# END>
# Training until now has taken 0 days 0 hours 17 minutes 44 seconds.
#
# ===== TRAINING 7-stage =====
# <BEGIN
# POS count : consumed   2048 : 2058
# NEG count : acceptanceRatio    75 : 0.198413
# Precalculation time: 5
# +----+---------+---------+
# |  N |    HR   |    FA   |
# +----+---------+---------+
# |   1|        1|        1|
# +----+---------+---------+
# |   2| 0.999512|     0.64|
# +----+---------+---------+
# |   3| 0.999512| 0.426667|
# +----+---------+---------+
# END>
# Training until now has taken 0 days 0 hours 19 minutes 41 seconds.
#
# ===== TRAINING 8-stage =====
# <BEGIN
# POS count : consumed   2048 : 2059
# NEG count : acceptanceRatio    75 : 0.101215
# Precalculation time: 5
# +----+---------+---------+
# |  N |    HR   |    FA   |
# +----+---------+---------+
# |   1|        1| 0.533333|
# +----+---------+---------+
# |   2|        1| 0.533333|
# +----+---------+---------+
# |   3|        1| 0.573333|
# +----+---------+---------+
# |   4|        1| 0.506667|
# +----+---------+---------+
# |   5|        1|     0.36|
# +----+---------+---------+
# END>
# Training until now has taken 0 days 0 hours 22 minutes 49 seconds.
#
# ===== TRAINING 9-stage =====
# <BEGIN
# POS count : consumed   2048 : 2059
# NEG count : acceptanceRatio    75 : 0.0652174
# Precalculation time: 6
# +----+---------+---------+
# |  N |    HR   |    FA   |
# +----+---------+---------+
# |   1|        1| 0.493333|
# +----+---------+---------+
# END>
# Training until now has taken 0 days 0 hours 23 minutes 44 seconds.
#
# ===== TRAINING 10-stage =====
# <BEGIN
# POS count : consumed   2048 : 2059
# NEG count : acceptanceRatio    75 : 0.0363196
# Precalculation time: 5
# +----+---------+---------+
# |  N |    HR   |    FA   |
# +----+---------+---------+
# |   1|        1| 0.546667|
# +----+---------+---------+
# |   2|        1| 0.546667|
# +----+---------+---------+
# |   3| 0.999023|     0.36|
# +----+---------+---------+
# END>
# Training until now has taken 0 days 0 hours 25 minutes 44 seconds.
#
# ===== TRAINING 11-stage =====
# <BEGIN
# POS count : consumed   2048 : 2061
# NEG count : acceptanceRatio    75 : 0.065388
# Precalculation time: 6
# +----+---------+---------+
# |  N |    HR   |    FA   |
# +----+---------+---------+
# |   1|        1|        1|
# +----+---------+---------+
# |   2|        1|        1|
# +----+---------+---------+
# |   3|        1| 0.573333|
# +----+---------+---------+
# |   4| 0.999023| 0.373333|
# +----+---------+---------+
# END>
# Training until now has taken 0 days 0 hours 28 minutes 13 seconds.
#
# ===== TRAINING 12-stage =====
# <BEGIN
# POS count : consumed   2048 : 2063
# NEG count : acceptanceRatio    75 : 0.0441176
# Precalculation time: 5
# +----+---------+---------+
# |  N |    HR   |    FA   |
# +----+---------+---------+
# |   1|        1| 0.813333|
# +----+---------+---------+
# |   2|        1| 0.813333|
# +----+---------+---------+
# |   3|        1| 0.826667|
# +----+---------+---------+
# |   4|        1|     0.84|
# +----+---------+---------+
# |   5|        1| 0.893333|
# +----+---------+---------+
# |   6|        1| 0.893333|
# +----+---------+---------+
# |   7| 0.999512| 0.546667|
# +----+---------+---------+
# |   8| 0.999512| 0.586667|
# +----+---------+---------+
# |   9| 0.999023| 0.146667|
# +----+---------+---------+
# END>
# Training until now has taken 0 days 0 hours 33 minutes 20 seconds.
#
# ===== TRAINING 13-stage =====
# <BEGIN
# POS count : consumed   2048 : 2065
# NEG count : acceptanceRatio    75 : 0.024217
# Precalculation time: 5
# +----+---------+---------+
# |  N |    HR   |    FA   |
# +----+---------+---------+
# |   1|        1|        1|
# +----+---------+---------+
# |   2|        1| 0.933333|
# +----+---------+---------+
# |   3|        1| 0.786667|
# +----+---------+---------+
# |   4| 0.999023|     0.52|
# +----+---------+---------+
# |   5| 0.999023|     0.56|
# +----+---------+---------+
# |   6| 0.999023| 0.306667|
# +----+---------+---------+
# END>
# Training until now has taken 0 days 0 hours 36 minutes 54 seconds.

# %%
old = os.path.join(data, 'cascade.xml')
new = os.path.join(data, '%s_cascade.xml' % obj)
# !mv {old} {new}
